# %%
import pandas as pd
dataset = pd.get_dummies(pd.read_csv('insurance_pre.csv'),dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

estimator = {
    'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'max_features':['sqrt', 'log2', None],
    'n_estimators':[50,100]

}

grid = GridSearchCV(RandomForestRegressor(),estimator,verbose=3,refit=True,n_jobs=-1)

# %%
re = grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\vignesh_s\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
table = pd.DataFrame.from_dict(re.cv_results_)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.301901      0.006829         0.020044        0.003605
# 1        0.579485      0.004629         0.024591        0.001703
# 2        0.316084      0.020674         0.017490        0.004353
# 3        0.557811      0.011087         0.024998        0.002810
# 4        0.395462      0.035905         0.016746        0.002739
# 5        0.882964      0.032900         0.026039        0.003384
# 6        1.376360      0.072263         0.016484        0.004098
# 7        2.424653      0.122759         0.026932        0.005844
# 8        1.220369      0.037829         0.013221        0.002062
# 9        2.148478      0.080675         0.020353        0.000600
# 10       1.889450      0.076995         0.012266        0.001866
# 11       3.743026      0.101816         0.022143        0.003376
# 12       0.271238      0.002171         0.012276        0.001550
# ...

# %%
print(f'BEST PARAMETERS: {grid.best_params_}')
# Out:
# BEST PARAMETERS: {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}

# %%
re.predict([[20,20,1,0,0]])
# Out:
# C:\Users\vignesh_s\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2628.785199])
