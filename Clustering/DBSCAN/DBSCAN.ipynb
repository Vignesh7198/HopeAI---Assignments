# %%
import pandas as pd
dataset = pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = dataset.iloc[:,3:]

# %%
from sklearn.cluster import DBSCAN

# %%
cluster = DBSCAN(eps=10,min_samples=5,metric='euclidean', metric_params=None,leaf_size=30,p=2,n_jobs=1)

# %%
predictedClusters = cluster.fit_predict(x)
# Out:
# C:\Users\vignesh_s\AppData\Local\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\vignesh_s\AppData\Local\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):

# %%
unsupervised = dataset.copy()
unsupervised["cluster"] = predictedClusters

# %%
import seaborn as sb

# %%
sb.lmplot(data=unsupervised, x=unsupervised.columns[3],y=unsupervised.columns[4],hue=unsupervised.columns[5],fit_reg=False)
