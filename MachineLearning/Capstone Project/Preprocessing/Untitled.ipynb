# %% [markdown]
# ## Load the dataset (Anxiety.csv)

# %%
import pandas as pd
dataset = pd.read_csv("Anxiety.csv")
dataset
# Out:
#      1. Age 2. Gender                                      3. University  \
# 0     18-22    Female           Independent University, Bangladesh (IUB)
# 1     18-22      Male           Independent University, Bangladesh (IUB)
# 2     18-22      Male  American International University Bangladesh (...
# 3     18-22      Male  American International University Bangladesh (...
# 4     18-22      Male                       North South University (NSU)
# ...     ...       ...                                                ...
# 2023  18-22      Male                              Dhaka University (DU)
# 2024  18-22    Female           Bangladesh Agricultural University (BAU)
# 2025  18-22      Male  American International University Bangladesh (...
# 2026  23-26    Female                              Dhaka University (DU)
# 2027  18-22      Male           Independent University, Bangladesh (IUB)
#
#                                      4. Department           5. Academic Year  \
# ...

# %% [markdown]
# ## Checking the presence of null value

# %%
dataset.isnull().sum()
# Out:
# 1. Age                                                                                                          0
# 2. Gender                                                                                                       0
# 3. University                                                                                                   0
# 4. Department                                                                                                   0
# 5. Academic Year                                                                                                0
# 6. Current CGPA                                                                                                 0
# 7. Did you receive a waiver or scholarship at your university?                                                  0
# 1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure?                      0
# ...

# %% [markdown]
# # Dataset appears to be good, without any null values

# %% [markdown]
# # Let's remove the unwanted columns

# %%
x = dataset.iloc[:,0:7]

# %%
x.head(2)
# Out:
#   1. Age 2. Gender                             3. University  \
# 0  18-22    Female  Independent University, Bangladesh (IUB)
# 1  18-22      Male  Independent University, Bangladesh (IUB)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
#
#   6. Current CGPA  \
# 0     2.50 - 2.99
# 1     3.00 - 3.39
#
#   7. Did you receive a waiver or scholarship at your university?
# 0                                                 No
# 1                                                 No

# %%
y=dataset.iloc[:,-1]

# %%
y.value_counts()
# Out:
# Severe Anxiety      744
# Moderate Anxiety    620
# Mild Anxiety        505
# Minimal Anxiety     159
# Name: Anxiety Label, dtype: int64

# %% [markdown]
# ## This seems to be a multiclass statement, let's convert this to a binary class, coz accuracy will drop when there is more classes and less number of samples

# %%
y = y.map(lambda y: "Less Anxious" if y=="Minimal Anxiety" else "More Anxious");

# %%
y.value_counts()
# Out:
# More Anxious    1869
# Less Anxious     159
# Name: Anxiety Label, dtype: int64

# %% [markdown]
# ## Lets's join the dependent (y) and independent (x) variable and save it in csv file for future process

# %%
dataset = pd.concat([x,y],axis=1)

# %%
dataset.to_csv('C:\\Users\\Vignesh S\\Desktop\\HopeAI\MachineLearning\\Capstone Project\\Univariate & Bivariate\\PreAnxiety.csv',index=False)
